# %% [markdown]
# # SCRAPING FROM AMAZON LINK OF ONE SMARTPHONE

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests

# %%
link = "https://www.amazon.in/gp/product/B07KXC7QS4/ref=s9_acss_bw_cg_Budget_4a1_w?pf_rd_m=A1K21FY43GMZF8&pf_rd_s=merchandised-search-14&pf_rd_r=56NQ9CKPAV7G9Q3NV9AK&pf_rd_t=101&pf_rd_p=9bb12955-a142-400a-a386-03656de054dc&pf_rd_i=1389401031"

link2 = "https://www.amazon.in/gp/product/B078BN2H3R/ref=s9_acss_bw_cg_Budget_2a1_w?pf_rd_m=A1K21FY43GMZF8&pf_rd_s=merchandised-search-14&pf_rd_r=56NQ9CKPAV7G9Q3NV9AK&pf_rd_t=101&pf_rd_p=9bb12955-a142-400a-a386-03656de054dc&pf_rd_i=1389401031"

link3 = "https://www.amazon.in/gp/product/B0869BGNLD/ref=s9_acss_bw_cg_Budget_6b1_w?pf_rd_m=A1K21FY43GMZF8&pf_rd_s=merchandised-search-14&pf_rd_r=PDMD83GCDFGQJZEBVMY8&pf_rd_t=101&pf_rd_p=9bb12955-a142-400a-a386-03656de054dc&pf_rd_i=1389401031"

link4 = "https://www.amazon.in/gp/product/B082P36B9X/ref=s9_acss_bw_cg_Budget_5d1_w?pf_rd_m=A1K21FY43GMZF8&pf_rd_s=merchandised-search-14&pf_rd_r=PDMD83GCDFGQJZEBVMY8&pf_rd_t=101&pf_rd_p=9bb12955-a142-400a-a386-03656de054dc&pf_rd_i=1389401031"

# %%
page = requests.get(link)
page
# Out:
# <Response [200]>

# %%
# page.content

# %%
soup = bs(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:feature:aui-assets -->
# ...

# %%
names = soup.find_all("span", class_ = "a-profile-name")
names
# Out:
# [<span class="a-profile-name">Vijender Singh</span>,
#  <span class="a-profile-name">Jithy</span>,
#  <span class="a-profile-name">nadeem</span>,
#  <span class="a-profile-name">Steal Best Deals</span>,
#  <span class="a-profile-name">Amazon Customer</span>,
#  <span class="a-profile-name">Yathiraj</span>,
#  <span class="a-profile-name">Gulab panaskar</span>,
#  <span class="a-profile-name">Soumalya Chakraborty</span>]

# %%
c_name = []
for i in range(0, len(names)):
                  c_name.append(names[i].get_text())
c_name
# Out:
# ['Vijender Singh',
#  'Jithy',
#  'nadeem',
#  'Steal Best Deals',
#  'Amazon Customer',
#  'Yathiraj',
#  'Gulab panaskar',
#  'Soumalya Chakraborty']

# %%
titles = soup.find_all("a", class_ = "review-title")
titles
# Out:
# [<a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R1OMAB0BNJK7H0?ASIN=B07KXC7QS4">
#  <span>Its a balanced phone....great on all fronts.....the display,sound, performance, battery life 👌</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R14I2XIFCX0XN4?ASIN=B07KXC7QS4">
#  <span>Happy for the before time delivery but the phone had a software glitch.</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R3BEZYRLWBJ09?ASIN=B07KXC7QS4">
#  <span>Bad product Samsung s10 plus</span>
#  </a>,
# ...

# %%
r_title = []
for j in range(0, len(titles)):
                  r_title.append(titles[j].get_text())
r_title
# Out:
# ['\nIts a balanced phone....great on all fronts.....the display,sound, performance, battery life 👌\n',
#  '\nHappy for the before time delivery but the phone had a software glitch.\n',
#  '\nBad product Samsung s10 plus\n',
#  '\nFirst phone from samsung👍👍\n',
#  '\nVery bad experience with my first Samsung phone...\n',
#  '\nSamsung Galaxy S10 plus #1 Phone of the year\n',
#  '\nSamsung offer\n',
#  '\nExcellent Cameras and Performance\n']

# %%
r_title[:] = [titles.rstrip('\n') for titles in r_title]
r_title[:] = [titles.lstrip('\n') for titles in r_title]
r_title
# Out:
# ['Its a balanced phone....great on all fronts.....the display,sound, performance, battery life 👌',
#  'Happy for the before time delivery but the phone had a software glitch.',
#  'Bad product Samsung s10 plus',
#  'First phone from samsung👍👍',
#  'Very bad experience with my first Samsung phone...',
#  'Samsung Galaxy S10 plus #1 Phone of the year',
#  'Samsung offer',
#  'Excellent Cameras and Performance']

# %%
stars = soup.find_all("i", class_ = "review-rating")
stars
# Out:
# [<i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-1 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">1.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-1 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">1.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
# ...

# %%
rating = []
for j in range(0, len(stars)):
                  rating.append(stars[j].get_text())
rating
# Out:
# ['5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars']

# %%
review_data = soup.find_all("span", {'data-hook' : 'review-body'})
review_data
# Out:
# [<span class="a-size-base review-text" data-hook="review-body"><div aria-live="polite" class="a-expander-collapsed-height a-row a-expander-container a-expander-partial-collapse-container" data-a-expander-collapsed-height="300" data-a-expander-name="review_text_read_more" style="max-height:300px"><div aria-expanded="false" class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content" data-hook="review-collapsed">
#  <span>
# ...

# %%
reviews = []
for j in range(0, len(review_data)):
                  reviews.append(review_data[j].get_text())
# reviews

# %%
reviews[:] = [review_data.lstrip('\n') for review_data in reviews]
reviews[:] = [review_data.lstrip('\n') for review_data in reviews]

reviews
# Out:
# ["  The phone looks gorgeous....the build and design is top notch....and the display is best in class, amazing contrast ,colour and brightness, visibility in sunlight is perfect,great battery life , ultra smooth UI, the physical size is perfect (can be handled easily).The ultra wide lens take great,unique shots , dynamic range is improved from previous generation,front camera is good but not able to match to iphone xs max or pixel.Bundled AKG headfones sound awesome and the speaker on this phone are loud and sound great....calling is pleasure ( sufficient loundness of mic input and earpiece output)The Ultrasonic fingerprint sensor works great....but sometime misses as the physical sensor area is tiny....but it's more secure than an optical indisplay sensor.The only weak point is i think front camera (though being very good)Anyone thinking of buying it ....go ahead guys the looks and screen on this phone are exceptional.....and every other thing is great too.\n\nRead more",
# ...

# %%
len(reviews)
# Out:
# 8

# %%
# c_name
# r_title
# rating
# reviews

# %%
df = pd.DataFrame()

# %%
df['Customer Name'] = c_name
df['Review Title'] = r_title
df['Review Rating'] = rating
df['Review'] = reviews

# %%
df
# Out:
#           Customer Name                                       Review Title  \
# 0        Vijender Singh  Its a balanced phone....great on all fronts......
# 1                 Jithy  Happy for the before time delivery but the pho...
# 2                nadeem                       Bad product Samsung s10 plus
# 3      Steal Best Deals                         First phone from samsung👍👍
# 4       Amazon Customer  Very bad experience with my first Samsung phon...
# 5              Yathiraj       Samsung Galaxy S10 plus #1 Phone of the year
# 6        Gulab panaskar                                      Samsung offer
# 7  Soumalya Chakraborty                  Excellent Cameras and Performance
#
#         Review Rating                                             Review
# 0  5.0 out of 5 stars    The phone looks gorgeous....the build and de...
# 1  4.0 out of 5 stars    Got the phone on time (7th March 19 morning)...
# 2  1.0 out of 5 stars    1st day mobile is dead and service centre re...
# ...

# %%
import requests
from bs4 import BeautifulSoup as bs

r = requests.get('https://www.amazon.in/gp/bestsellers/electronics/1389432031?ref_=Oct_s9_apbd_obs_hd_bw_b1W1uk3_S&pf_rd_r=A5KTFPPSRY5SWGGPC9Q0&pf_rd_p=83e0d721-0df4-562e-84f3-d2c4f07aa3b9&pf_rd_s=merchandised-search-10&pf_rd_t=BROWSE&pf_rd_i=1389432031')
soup = bs(r.content, 'lxml')
items = [item['alt'] for item in soup.select('.a-link-normal [alt]')]
print(items)
# Out:
# ['Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128GB Storage)', 'Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64GB Storage)', 'OnePlus Nord 5G (Blue Marble, 12GB RAM, 256GB Storage)', 'Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)', 'Redmi Note 9 (Pebble Grey, 4GB RAM 128GB Storage) - 48MP Quad Camera & Full HD+ Display', 'Samsung Galaxy M31s (Mirage Blue, 8GB RAM, 128GB Storage)', 'Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage) – Dual Cameras & 5,000 mAH Battery', 'OnePlus Nord 5G (Gray Onyx, 8GB RAM, 128GB Storage)', 'OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB Storage)', 'OnePlus Nord 5G (Gray Onyx, 12GB RAM, 256GB Storage)', 'Redmi Note 9 (Scarlet Red, 4GB RAM, 64GB Storage) - 48MP Quad Camera & Full HD+ Display', 'Samsung Galaxy M31 (Space Black, 6GB RAM, 128GB Storage)', 'Redmi Note 9 Pro Max (Aurora Blue, 6GB RAM, 128GB Storage) - 64MP Quad Camera & Latest 8nm Snapdragon 720G', 'Samsung Galaxy M31s (Mirage Black, 6GB RAM, 128GB Storage)', 'Redmi 8A Dual (Sea Blue, 3GB
# ...

# %%
mlink = 'https://www.amazon.in/s/ref=lp_1389401031_nr_n_1?fst=as%3Aoff&rh=n%3A976419031%2Cn%3A%21976420031%2Cn%3A1389401031%2Cn%3A1389432031&bbn=1389401031&ie=UTF8&qid=1596782309&rnid=1389401031'


mpage = requests.get(mlink)
mpage
# Out:
# <Response [200]>

# %%
soup = bs(mpage.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo">
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!--  emit CSM JS -->
#   <style>
# ...

# %%
for div in soup.findAll('div', attrs={'class':'image'}):
    print(div.find('a')['href'])
    print(div.find('a').contents[0])
    print(div.find('img')['src'])
